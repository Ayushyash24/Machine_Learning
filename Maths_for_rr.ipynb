# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayushyash24/Machine_Learning/blob/main/Maths_for_rr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![rr1.png](data:image/png;base64,...)

# %% [markdown]
# ![rr2.png](data:image/png;base64,...)

# %% [markdown]
# ![r3.png](data:image/png;base64,...)
