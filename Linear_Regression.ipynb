# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayushyash24/Machine_Learning/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Linear Regression
#
# Linear Regression is a supervised machine learning algorithm used to model the relationship between input variables (features) and a continuous output.
#
# Because the relationship between input and output is assumed to be linear (straight-line relationship).
#
# y=mx+b
#
#
#
#
# Suppose you want to predict house price based on area (sq ft).
#
# Input (X): Area
#
# Output (Y): Price
#
#
# ![Simple-Linear-Regression2.avif](data:image/avif;base64,...)

# %% [markdown]
# -------------------------------------------------------------------
# Stochastic errors are random, unpredictable errors that occur due to chance or randomness, not because of a fixed mistake in the model or data collection process.
