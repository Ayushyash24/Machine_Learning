# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayushyash24/Machine_Learning/blob/main/Mathematics_for_LR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![S1.png](data:image/png;base64,...)

# %% [markdown]
# ![S2.png](data:image/png;base64,...)

# %% [markdown]
# ![S3.png](data:image/png;base64,...)

# %% [markdown]
# ![S4.png](data:image/png;base64,...)

# %% [markdown]
# ![S5.png](data:image/png;base64,...)
